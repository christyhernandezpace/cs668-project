# %% [markdown]
# # Educational Equity in New Jersey:
# ## Analyzing Relationships Between Resources and Outcomes Across School Districts

# %% [markdown]
# -----------------------------------------------------

# %% [markdown]
# ### Christy Hernandez
# #### CS 668 - Pace University - Fall 2024

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# As said in my Project Overview Statement:
#
# New Jersey is my home state – as well as home to a diverse population and a wide range of school districts, from affluent suburban areas to urban centers and rural communities. However, this diversity presents a challenge: significant disparities in educational resources, funding, and student outcomes persist across different districts. This imbalance in resources has direct implications on student performance, educational opportunities, and overall equity within the state's educational system. Addressing these disparities, especially the most impactful ones, can lead to more targeted policy interventions and an overall improvement in educational outcomes across New Jersey.
#
# In response to this opportunity, the goal of this project is to conduct a comprehensive analysis of educational equity across school districts in New Jersey, identifying relationships between resources and student outcomes. By examining factors such as funding, teacher-student ratios, and access to technology, the analysis will identify which variables have the most impact on student success. The project will evaluate and propose evidence-based interventions, like increased school funding or mentorship programs, aimed at closing the achievement gap. The final deliverable will be a machine learning model that predicts the potential impact of these interventions on educational outcomes, particularly in underserved communities. This model will allow us to highlight specific areas where inequities are most pronounced and propose targeted, data-driven solutions to address them. By leveraging pre-existing and publicly available datasets from the State of New Jersey, I aim to generate actionable insights that can guide state and local policymakers in promoting a more equitable distribution of resources and improving educational outcomes.

# %% [markdown]
# ----------------------

# %% [markdown]
# Let's get started by importing pandas and loading the related dataset I found!

# %%
import pandas as pd

# %%
dataset = pd.read_excel('C:/Users/Christy Hernandez/OneDrive/Desktop/Pace Masters Work/CS Analytics Capstone Project/Source files/Database_DistrictStateDetail.xlsx', sheet_name = None)

# %% [markdown]
# Luckily, this dataset has a lot of features that should be able to provide a good analysis overall. Let's see just how many features there are:

# %%
print(f'There are {len(dataset)} features.')
# Out:
# There are 72 features.

# %% [markdown]
# Okay, and what are they?

# %%
print(dataset.keys())
# Out:
# dict_keys(['Important 2022-2023 Notes', 'Header and Contact', 'EnrollmentTrendsbyGrade', 'EnrollmentTrendsByStudentGroup', 'EnrollmentByRacialEthnicGroup', 'PreKAndK-FullDayHalfDay', 'EnrollmentTrendsFullSharedTime', 'EnrollmentByHomeLanguage', 'StudentGrowthTrends', 'StudentGrowth', 'StudentGrowthByGrade', 'StudentGrowthByPerformLevel', 'ELAMathPerformanceTrends', 'ELAParticipationPerformance', 'ELAPerformanceTrends', 'ELAPerformanceByGrade', 'MathParticipationPerformance', 'MathPerformanceTrends', 'MathPerformanceByGradeTest', 'ScienceAssessmentSummaryByGrade', 'ScienceAssessmentByGrade', 'AlternateAssessmentParticipatio', 'EnglishLangProgressToProficienc', 'NJGPA', 'EnglishLangParticipationPerform', 'NAEP', 'PSAT-SAT-ACTParticipation', 'PSAT-SAT-ACTPerformance', 'APIBCourseworkPartPerf', 'APIBDualEnrPartByStudentGrp', 'APIBCoursesOffered', 'CTE_SLEParticipation', 'CTEParticipationByStudentGroup', 'WorkbasedLearningByCareerClust', 'IndustryValuedCredentialsEarned', 'MathCourseParticipation', 'ScienceCourseParticipation', 'WorldLanguagesCourseParticipati', 'SocStudiesHistoryCourseParticip', 'ComputerScienceCourseParticipat', 'SealofBiliteracy', 'VisualAndPerformingArts', 'GraduatonRateTrendsProgress', '4YrGraduationCohortProfile', '5YrGraduationCohortProfile', '6YrGraduationCohortProfile', 'FederalGraduationRates', 'AccountabilityGraduationRates', 'DropoutRateTrends', 'PostsecondaryEnrRatesFall', 'PostsecondaryEnrRates16mos', 'Apprenticeship', 'ChronicAbsenteeism', 'DaysAbsent', 'ChronicAbsenteeismByGrade', 'ViolenceVandalismHIBSubstanceOf', 'HIBInvestigations', 'PoliceNotifications', 'DisciplinaryRemovals', 'TeachersExperience', 'AdministratorsExperience', 'TeachersAdminsDemographics', 'StaffCounts', 'StudentToStaffRatios', 'TeachersAdminsLevelOfEducation', 'TeachersAdminsOneYearRetention', 'TeachersBySubjectArea', 'StatewideEducatorEquity', 'CompTargetedList', 'ESSAAccountabilityProgress', 'AccountabilitySummary', 'Narrative'])

# %% [markdown]
# Okay, well, 72 is a lot, and I was sure that not all of them would be very useful here. So, I went through the dataset manually and found 16 features that I think will assist with this project the most! Here is what they are and what they each contain:

# %% [markdown]
# 1.	'EnrollmentTrendsbyGrade'
# o	Includes the total student enrollment for each district.
#
# 2.	'EnrollmentTrendsByStudentGroup'
# o	Percentages of district student population by gender, economic disadvantage, disability, English learning, homelessness, foster care, military-connection, and migrant
#
# 3.	'StudentGrowthTrends'
# o	For each district, for the subject Math and then English Language Arts (ELA), what was the median student growth percentile, and then did it meet state standards (options are ‘Not Met’, ‘Met Standard’, or ‘Exceeds Standards’)
#
# 4.	‘PSAT-SAT-ACTParticipation’
# o	Percentage of student participation for each standardized exam type for each district, and then the state average participation rate for each exam.
#
# 5.	‘APIBCourseworkPartPerf’
# o	Percentage of students in each district that are enrolled in one or more AP or IB course, then percentage for one or more AP or IB exam, then percentage for one or more dual enrollment course, followed by the state averages for each.
#
# 6.	‘4YrGraduationCohortProfile’
# o	After 4 years of enrollment, for each student group within each district, the percentage of students graduating, then the percentage continuing, then the percentage not continuing, followed by the state averages for each.
#
# 7.	‘DropoutRateTrends’
# o	Percentage of students who drop out by district, followed by the state average.
#
# 8.	'PostsecondaryEnrRatesFall'
# o	For the fall semester following high school graduation, for each student group within each district, range of percentage of students who are enrolled in post-secondary education, as well as the districtwide and statewide percentage ranges.
#
# 9.	‘ChronicAbsenteeism'
# o	For each student group for each district, the percentage of students who are chronically absent, as well as the districtwide percentage.
#
# 10.	'ViolenceVandalismHIBSubstanceOf'
# o	For each district, incidents per 100 students enrolled
#
# 11.	'DisciplinaryRemovals'
# o	For each district, the percentage of students who received suspension, expulsion, and arrest.
#
# 12.	‘TeachersExperience’
# o	For each district, the average number of years of total experience, then the average number of years of experience in their current district, followed by the state averages for both
#
# 13.	‘AdministratorsExperience’
# o	For each district, the average number of years of total experience, then the average number of years of experience in their current district, followed by the state averages for both
#
# 14.	'StudentToStaffRatios'
# o	For each district, staff to student ratios for different staff positions – Teacher, Admin, Librarian, Nurse, Counselor, etc., as well as a Teacher to Admin ratio.
#
# 15.	‘TeachersAdminsLevelofEducation’
# o	For teachers and then administrators in each district, the percentage that has achieved a maximum of a bachelors, then a maximum of a masters, then a maximum of a doctorate.
#
# 16.	‘TeachersAdminsOneYearRetention’
# o	For teachers and then administrators, the percentage of retention for each district, and then for the state.

# %% [markdown]
# Now that we know which features we want to use, let's create a separate dictionary that has only these features.

# %%
desired_data = {}

# %%
desired_sheets = ['EnrollmentTrendsbyGrade', 'EnrollmentTrendsByStudentGroup', 'StudentGrowthTrends', 'PSAT-SAT-ACTParticipation', 'APIBCourseworkPartPerf', '4YrGraduationCohortProfile', 'DropoutRateTrends', 'PostsecondaryEnrRatesFall', 'ChronicAbsenteeism', 'ViolenceVandalismHIBSubstanceOf', 'DisciplinaryRemovals', 'TeachersExperience', 'AdministratorsExperience', 'StudentToStaffRatios', 'TeachersAdminsLevelOfEducation', 'TeachersAdminsOneYearRetention']

# %%
desired_data = {sheet_name: dataset[sheet_name] for sheet_name in desired_sheets if sheet_name in dataset}

# %% [markdown]
# Great, now let's take a look at our modified dataset!

# %%
for sheet_name, sheet_data in desired_data.items():
    print(f'In regards to the "{sheet_name}" sheet:\n')
    print(desired_data[sheet_name].head(),"\n---------------------------------------\n")
# Out:
# In regards to the "EnrollmentTrendsbyGrade" sheet:
#
#   CountyCode CountyName DistrictCode  \
# 0         01   Atlantic         0010
# 1         01   Atlantic         0110
# 2         01   Atlantic         0120
# 3         01   Atlantic         0125
# 4         01   Atlantic         0570
#
#                                        DistrictName  GradePK  GradeKG  \
# 0                   Absecon Public Schools District      135       90
# 1                     Atlantic City School District      531      463
# 2        Atlantic County Vocational School District        0        0
# 3  Atlantic County Special Services School District       20       15
# 4                 Brigantine Public School District       60       39
#
#    Grade01  Grade02  Grade03  Grade04  Grade05  Grade06  Grade07  Grade08  \
# 0       74       88       86       75      106      102      105       92
# 1      446      416      439      425      490      418      473      467
# 2        0        0        0        0        0        0        0        0
# 3       16       23       20       26       20       19       23       14
# 4       39       28       36       35       36       44       33       34
#
#    Grade09  Grade10  Grade11  Grade12  Total
# 0        0        0        0        0    953
# 1      520      446      351      406   6291
# 2      456      461      409      394   1720
# 3       21       20       19       70    326
# 4        0        0        0        0    384
# ---------------------------------------
#
# In regards to the "EnrollmentTrendsByStudentGroup" sheet:
#
#   CountyCode CountyName DistrictCode  \
# 0         01   Atlantic         0010
# 1         01   Atlantic         0110
# 2         01   Atlantic         0120
# 3         01   Atlantic         0125
# 4         01   Atlantic         0570
#
#                                        DistrictName Female Male  \
# 0                   Absecon Public Schools District     47   53
# 1                     Atlantic City School District     48   52
# 2        Atlantic County Vocational School District     57   42
# 3  Atlantic County Special Services School District     28   72
# 4                 Brigantine Public School District     52   48
#
#   Non-Binary/Undesignated Gender  Economically Disadvantaged Students  \
# 0                            ≤1%                                 49.4
# 1                            ≤1%                                 87.1
# 2                            ≤1%                                 53.8
# 3                            ≤1%                                 41.1
# 4                            ≤1%                                 31.5
#
#    Students with Disabilities  English Learners  Homeless Students  \
# 0                        17.3               7.8                1.9
# 1                        15.0              18.7                2.0
# 2                         8.1               0.0                0.5
# 3                        99.4               0.3                2.5
# 4                        18.0               4.2                1.8
#
#    Students in Foster Care  Military-Connected Students  Migrant Students
# 0                      0.4                          0.5               0.0
# 1                      0.2                          0.5               0.0
# 2                      0.0                          0.9               0.0
# 3                      1.5                          0.3               0.0
# 4                      0.3                          1.6               0.0
# ---------------------------------------
#
# In regards to the "StudentGrowthTrends" sheet:
#
#   CountyCode CountyName DistrictCode                       DistrictName  \
# 0         01   Atlantic         0010    Absecon Public Schools District
# 1         01   Atlantic         0010    Absecon Public Schools District
# 2         01   Atlantic         0110      Atlantic City School District
# 3         01   Atlantic         0110      Atlantic City School District
# 4         01   Atlantic         0570  Brigantine Public School District
#
#   SchoolYear Subject MedianStudentGrowthPercentile       MetStandard  \
# 0  2022-2023     ELA                            52      Met Standard
# 1  2022-2023    Math                            54      Met Standard
# 2  2022-2023    Math                            43      Met Standard
# 3  2022-2023     ELA                            48      Met Standard
# 4  2022-2023     ELA                            61  Exceeds Standard
#
#    StateMedianStudentGrowthPercentile
# 0                                  50
# 1                                  50
# 2                                  50
# 3                                  50
# 4                                  50
# ---------------------------------------
#
# In regards to the "PSAT-SAT-ACTParticipation" sheet:
#
#   CountyCode CountyName DistrictCode  \
# 0         01   Atlantic         0110
# 1         01   Atlantic         0120
# 2         01   Atlantic         0590
# 3         01   Atlantic         1310
# 4         01   Atlantic         1790
#
#                                        DistrictName   SAT  ACT  PSAT  \
# 0                     Atlantic City School District  36.9  3.2  74.9
# 1        Atlantic County Vocational School District  48.7  0.0  95.7
# 2                    Buena Regional School District  28.8  0.9  64.9
# 3               Egg Harbor Township School District  49.8  0.9  90.8
# 4  Greater Egg Harbor Regional High School District  89.5  2.4  89.1
#
#    STATE_SAT  STATE_ACT  STATE_PSAT
# 0       61.9        7.7        78.3
# 1       61.9        7.7        78.3
# 2       61.9        7.7        78.3
# 3       61.9        7.7        78.3
# 4       61.9        7.7        78.3
# ---------------------------------------
#
# In regards to the "APIBCourseworkPartPerf" sheet:
#
#   CountyCode CountyName DistrictCode  \
# 0         01   Atlantic         0110
# 1         01   Atlantic         0120
# 2         01   Atlantic         0590
# 3         01   Atlantic         1310
# 4         01   Atlantic         1790
#
#                                        DistrictName  APIB_COURSE_DISTRICT  \
# 0                     Atlantic City School District                  20.7
# 1        Atlantic County Vocational School District                  15.2
# 2                    Buena Regional School District                  27.5
# 3               Egg Harbor Township School District                  32.8
# 4  Greater Egg Harbor Regional High School District                  25.6
#
#    APIB_COURSE_STATE  APIB_EXAM_DISTRICT  APIB_EXAM_STATE AP3_IB4_DISTRICT  \
# 0               34.9                15.1             29.7                *
# 1               34.9                10.0             29.7                *
# 2               34.9                10.2             29.7                *
# 3               34.9                29.3             29.7             22.0
# 4               34.9                14.6             29.7                *
#
#    AP3_IB4_STATE  DUAL_DISTRICT  DUAL_STATE
# 0           21.3            0.0        24.0
# 1           21.3           29.9        24.0
# 2           21.3            0.0        24.0
# 3           21.3           41.7        24.0
# 4           21.3           16.1        24.0
# ---------------------------------------
#
# In regards to the "4YrGraduationCohortProfile" sheet:
#
#   CountyCode CountyName DistrictCode                   DistrictName  \
# 0         01   Atlantic         0110  Atlantic City School District
# 1         01   Atlantic         0110  Atlantic City School District
# 2         01   Atlantic         0110  Atlantic City School District
# 3         01   Atlantic         0110  Atlantic City School District
# 4         01   Atlantic         0110  Atlantic City School District
#
#                                   StudentGroup Graduates Continuing Students  \
# 0                                 Districtwide      79.8                 4.2
# 1                                        White      85.2                 3.7
# 2                                     Hispanic      75.6                 4.5
# 3                    Black or African American      73.6                 5.6
# 4  Asian, Native Hawaiian, or Pacific Islander      93.5                 2.2
#
#   Non-Continuing Student State: Graduates State: Continuing Students  \
# 0                   15.9             91.1                        3.8
# 1                   11.1             95.0                        2.6
# 2                   19.9             85.8                        5.0
# 3                   20.8             86.7                        5.7
# 4                    4.3             96.7                        2.2
#
#   State: Non-Continuing Student
# 0                           5.1
# 1                           2.4
# 2                           9.2
# 3                           7.6
# 4                           1.1
# ---------------------------------------
#
# In regards to the "DropoutRateTrends" sheet:
#
#   CountyCode CountyName DistrictCode  \
# 0         01   Atlantic         0110
# 1         01   Atlantic         0120
# 2         01   Atlantic         0590
# 3         01   Atlantic         1310
# 4         01   Atlantic         1790
#
#                                        DistrictName  Dropout_District  \
# 0                     Atlantic City School District               2.9
# 1        Atlantic County Vocational School District               0.2
# 2                    Buena Regional School District               1.0
# 3               Egg Harbor Township School District               0.9
# 4  Greater Egg Harbor Regional High School District               1.9
#
#    Dropout_State
# 0            1.2
# 1            1.2
# 2            1.2
# 3            1.2
# 4            1.2
# ---------------------------------------
#
# In regards to the "PostsecondaryEnrRatesFall" sheet:
#
#   CountyCode CountyName DistrictCode                   DistrictName  \
# 0         01   Atlantic         0110  Atlantic City School District
# 1         01   Atlantic         0110  Atlantic City School District
# 2         01   Atlantic         0110  Atlantic City School District
# 3         01   Atlantic         0110  Atlantic City School District
# 4         01   Atlantic         0110  Atlantic City School District
#
#                 StudentGroup EnrolledPercent Enrolled2Yr Enrolled4Yr
# 0                  Statewide      69.8-72.0%        25.2        74.8
# 1               Districtwide      54.1-55.7%        23.5        76.5
# 2                      White      64.6-66.6%        16.1        83.9
# 3                   Hispanic      40.1-41.4%        47.4        52.6
# 4  Black or African American      42.3-43.7%        27.7        72.3
# ---------------------------------------
#
# In regards to the "ChronicAbsenteeism" sheet:
#
#   CountyCode CountyName DistrictCode                     DistrictName  \
# 0         01   Atlantic         0010  Absecon Public Schools District
# 1         01   Atlantic         0010  Absecon Public Schools District
# 2         01   Atlantic         0010  Absecon Public Schools District
# 3         01   Atlantic         0010  Absecon Public Schools District
# 4         01   Atlantic         0010  Absecon Public Schools District
#
#                                   StudentGroup Chronic_Abs_Count  \
# 0                                 Districtwide               132
# 1                                        White                60
# 2                                     Hispanic                35
# 3                    Black or African American                20
# 4  Asian, Native Hawaiian, or Pacific Islander                 6
#
#   Chronic_Abs_Pct Target MetTarget
# 0            16.3   16.0   Not Met
# 1            15.5   16.0       Met
# 2            15.8   16.0       Met
# 3            19.0   16.0   Not Met
# 4            11.1   16.0       Met
# ---------------------------------------
#
# In regards to the "ViolenceVandalismHIBSubstanceOf" sheet:
#
#   CountyCode CountyName DistrictCode  \
# 0         01   Atlantic         0010
# 1         01   Atlantic         0110
# 2         01   Atlantic         0120
# 3         01   Atlantic         0125
# 4         01   Atlantic         0570
#
#                                        DistrictName  Violence  Weapons  \
# 0                   Absecon Public Schools District         0        0
# 1                     Atlantic City School District       106       23
# 2        Atlantic County Vocational School District         6        2
# 3  Atlantic County Special Services School District         6        0
# 4                 Brigantine Public School District         0        1
#
#    Vandalism  Substances  Harassment, Intimidation, Bullying (HIB)  \
# 0          0           3                                         5
# 1          7          35                                        47
# 2          0          21                                         9
# 3          0           1                                        10
# 4          0           0                                         6
#
#    Total Unique Incidents  Incidents Per 100 Students Enrolled
# 0                       8                                 0.84
# 1                     217                                 3.45
# 2                      37                                 2.15
# 3                      17                                 5.21
# 4                       7                                 1.82
# ---------------------------------------
#
# In regards to the "DisciplinaryRemovals" sheet:
#
#   CountyCode CountyName DistrictCode  \
# 0         01   Atlantic         0010
# 1         01   Atlantic         0110
# 2         01   Atlantic         0120
# 3         01   Atlantic         0125
# 4         01   Atlantic         0570
#
#                                        DistrictName  InSchool_Count  \
# 0                   Absecon Public Schools District               0
# 1                     Atlantic City School District             179
# 2        Atlantic County Vocational School District               4
# 3  Atlantic County Special Services School District               3
# 4                 Brigantine Public School District               4
#
#    InSchool_Pct  OutofSchool_Count  OutofSchool_Pct  AnySusp_Count  \
# 0           0.0                 10              1.0             10
# 1           2.8                256              4.1            290
# 2           0.2                 39              2.3             43
# 3           0.9                 33             10.1             33
# 4           1.0                  2              0.5              6
#
#    AnySusp_Pct  Removal_Count  Removal_Pct  Expulsion_Count  Expulsion_Pct  \
# 0          1.0              3          0.3                0            0.0
# 1          4.6              9          0.1                0            0.0
# 2          2.5              2          0.1                0            0.0
# 3         10.1              0          0.0                0            0.0
# 4          1.6              1          0.3                0            0.0
#
#    Arrest_Count  Arrest_Pct SchoolDaysMissed_OSS
# 0             0         0.0                   29
# 1            11         0.2                 1679
# 2             0         0.0                  344
# 3             2         0.6                   99
# 4             1         0.3                   46
# ---------------------------------------
#
# In regards to the "TeachersExperience" sheet:
#
#   CountyCode CountyName DistrictCode  \
# 0         01   Atlantic         0010
# 1         01   Atlantic         0110
# 2         01   Atlantic         0120
# 3         01   Atlantic         0125
# 4         01   Atlantic         0570
#
#                                        DistrictName  TeacherCount_District  \
# 0                   Absecon Public Schools District                   93.0
# 1                     Atlantic City School District                  649.0
# 2        Atlantic County Vocational School District                  144.0
# 3  Atlantic County Special Services School District                   25.0
# 4                 Brigantine Public School District                   60.0
#
#    TeacherCount_State  TeacherAvgYearsExp_District  TeacherAvgYearsExp_State  \
# 0              118882                         12.4                      12.5
# 1              118882                         14.2                      12.5
# 2              118882                          7.8                      12.5
# 3              118882                         16.0                      12.5
# 4              118882                         17.2                      12.5
#
#    TeacherAvgYearsExpInDistrict_District  TeacherAvgYearsExpInDistrict_State  \
# 0                                    9.8                                11.3
# 1                                   13.2                                11.3
# 2                                    7.7                                11.3
# 3                                   14.2                                11.3
# 4                                   16.0                                11.3
#
#    ... PercentageTeacherInDistrict4YearsOrMore_District  \
# 0  ...                                             60.9
# 1  ...                                             76.4
# 2  ...                                             70.1
# 3  ...                                             88.0
# 4  ...                                             86.7
#
#    PercentageTeacherInDistrict4YearsOrMore_State  \
# 0                                           74.8
# 1                                           74.8
# 2                                           74.8
# 3                                           74.8
# 4                                           74.8
#
#    NumberOfOutOfFieldTeachers_District  NumberOfOutOfFieldTeachers_State  \
# 0                                  1.0                              2811
# 1                                  5.0                              2811
# 2                                  7.0                              2811
# 3                                  0.0                              2811
# 4                                  0.0                              2811
#
#    PercentageOfOutOfFieldTeachers_District  \
# 0                                      1.1
# 1                                      0.8
# 2                                      4.9
# 3                                      0.0
# 4                                      0.0
#
#    PercentageOfOutOfFieldTeachers_State  \
# 0                                   2.4
# 1                                   2.4
# 2                                   2.4
# 3                                   2.4
# 4                                   2.4
#
#    NumberTeachersWithProvisionalCredentials_District  \
# 0                                                  7
# 1                                                 36
# 2                                                 16
# 3                                                  1
# 4                                                  3
#
#    NumberTeachersWithProvisionalCredentials_State  \
# 0                                            8605
# 1                                            8605
# 2                                            8605
# 3                                            8605
# 4                                            8605
#
#   PercentageTeachersWithProvisionalCredentials_District  \
# 0                                                7.5
# 1                                                5.5
# 2                                               11.1
# 3                                                4.0
# 4                                                5.0
#
#    PercentageTeachersWithProvisionalCredentials_State
# 0                                                7.3
# 1                                                7.3
# 2                                                7.3
# 3                                                7.3
# 4                                                7.3
#
# [5 rows x 22 columns]
# ---------------------------------------
#
# In regards to the "AdministratorsExperience" sheet:
#
#   CountyCode CountyName DistrictCode  \
# 0         01   Atlantic         0010
# 1         01   Atlantic         0110
# 2         01   Atlantic         0120
# 3         01   Atlantic         0125
# 4         01   Atlantic         0570
#
#                                        DistrictName AdminCount_District  \
# 0                   Absecon Public Schools District                   6
# 1                     Atlantic City School District                  34
# 2        Atlantic County Vocational School District                  15
# 3  Atlantic County Special Services School District                   5
# 4                 Brigantine Public School District                   4
#
#    AdminCount_State AdminAvgYearsExp_District  AdminAvgYearsExp_State  \
# 0              9952                      15.5                    16.1
# 1              9952                      20.5                    16.1
# 2              9952                       7.1                    16.1
# 3              9952                      16.6                    16.1
# 4              9952                      15.3                    16.1
#
#   AdminAvgYearsExpInDistrict_District  AdminAvgYearsExpInDistrict_State  \
# 0                                 2.5                              12.5
# 1                                19.4                              12.5
# 2                                 6.4                              12.5
# 3                                 8.6                              12.5
# 4                                 7.8                              12.5
#
#   NumberAdminsWith4OrMoreYearsExpInDistrict_District  \
# 0                                                  3
# 1                                                 32
# 2                                                 10
# 3                                                  5
# 4                                                  2
#
#    NumberAdminsWith4OrMoreYearsExpInDistrict_State  \
# 0                                             7675
# 1                                             7675
# 2                                             7675
# 3                                             7675
# 4                                             7675
#
#   PercentageAdminsWith4OrMoreYearsExpInDistrict_District  \
# 0                                               50.0
# 1                                               94.1
# 2                                               66.7
# 3                                              100.0
# 4                                               50.0
#
#    PercentageAdminsWith4OrMoreYearsExpInDistrict_State
# 0                                               77.9
# 1                                               77.9
# 2                                               77.9
# 3                                               77.9
# 4                                               77.9
# ---------------------------------------
#
# In regards to the "StudentToStaffRatios" sheet:
#
#   CountyCode CountyName DistrictCode  \
# 0         01   Atlantic         0010
# 1         01   Atlantic         0110
# 2         01   Atlantic         0120
# 3         01   Atlantic         0125
# 4         01   Atlantic         0570
#
#                                        DistrictName Student_Teacher_District  \
# 0                   Absecon Public Schools District                     10:1
# 1                     Atlantic City School District                     10:1
# 2        Atlantic County Vocational School District                     12:1
# 3  Atlantic County Special Services School District                     13:1
# 4                 Brigantine Public School District                      6:1
#
#   Student_Admin_District Teacher_Admin_District Student_Librarian_District  \
# 0                  159:1                   16:1                          N
# 1                  185:1                   19:1                     1258:1
# 2                  115:1                   10:1                     1720:1
# 3                   65:1                    5:1                          N
# 4                   96:1                   15:1                          N
#
#   Student_Nurse_District Student_Counselor_District  \
# 0                  477:1                      318:1
# 1                  629:1                      315:1
# 2                  573:1                      191:1
# 3                  163:1                      326:1
# 4                  192:1                      192:1
#
#   Student_ChildStudy_District School_Psychologists_District  \
# 0                        28:1                         953:1
# 1                        38:1                        1049:1
# 2                        28:1                         860:1
# 3                        32:1                         326:1
# 4                        14:1                         384:1
#
#   School_Social_Workers_District Student_Assistance_Coordinators_District  \
# 0                          477:1                                        N
# 1                          899:1                                   3146:1
# 2                          860:1                                        N
# 3                          163:1                                        N
# 4                          384:1                                        N
#
#   School_Safety_Specialists_District
# 0                                  N
# 1                             6291:1
# 2                             1720:1
# 3                              326:1
# 4                              384:1
# ---------------------------------------
#
# In regards to the "TeachersAdminsLevelOfEducation" sheet:
#
#   CountyCode CountyName DistrictCode  \
# 0         01   Atlantic         0010
# 1         01   Atlantic         0010
# 2         01   Atlantic         0110
# 3         01   Atlantic         0110
# 4         01   Atlantic         0120
#
#                                  DistrictName Teachers/Admins Bachelors  \
# 0             Absecon Public Schools District           Admin       NaN
# 1             Absecon Public Schools District        Teachers      60.4
# 2               Atlantic City School District           Admin       NaN
# 3               Atlantic City School District        Teachers      53.2
# 4  Atlantic County Vocational School District           Admin       NaN
#
#   Masters Doctoral
# 0    83.3     16.7
# 1    38.5      1.1
# 2    88.2     11.8
# 3    44.8      2.0
# 4    86.7     13.3
# ---------------------------------------
#
# In regards to the "TeachersAdminsOneYearRetention" sheet:
#
#   CountyCode CountyName DistrictCode  \
# 0         01   Atlantic         0010
# 1         01   Atlantic         0010
# 2         01   Atlantic         0110
# 3         01   Atlantic         0110
# 4         01   Atlantic         0120
#
#                                  DistrictName Teachers/Admins  \
# 0             Absecon Public Schools District  Administrators
# 1             Absecon Public Schools District        Teachers
# 2               Atlantic City School District  Administrators
# 3               Atlantic City School District        Teachers
# 4  Atlantic County Vocational School District  Administrators
#
#   RetentionPct_District  RetentionPct_State
# 0                  83.3                86.6
# 1                  88.5                88.4
# 2                  91.2                86.6
# 3                  93.3                88.4
# 4                  78.6                86.6
# ---------------------------------------

# %% [markdown]
# Now let's see how many NaNs exist for each feature.

# %%
print(f'There are {len(desired_data)} features.\n')
for sheet_name, sheet_data in desired_data.items():
    number_of_nans = sheet_data.isnull().sum().sum()
    print(f'Sheet "{sheet_name}" contains {number_of_nans} null/NaN values.\n')
# Out:
# There are 16 features.
#
# Sheet "EnrollmentTrendsbyGrade" contains 0 null/NaN values.
#
# Sheet "EnrollmentTrendsByStudentGroup" contains 0 null/NaN values.
#
# Sheet "StudentGrowthTrends" contains 2 null/NaN values.
#
# Sheet "PSAT-SAT-ACTParticipation" contains 3 null/NaN values.
#
# Sheet "APIBCourseworkPartPerf" contains 4 null/NaN values.
#
# Sheet "4YrGraduationCohortProfile" contains 51 null/NaN values.
#
# Sheet "DropoutRateTrends" contains 1 null/NaN values.
#
# Sheet "PostsecondaryEnrRatesFall" contains 0 null/NaN values.
#
# Sheet "ChronicAbsenteeism" contains 9120 null/NaN values.
#
# Sheet "ViolenceVandalismHIBSubstanceOf" contains 0 null/NaN values.
#
# Sheet "DisciplinaryRemovals" contains 0 null/NaN values.
#
# Sheet "TeachersExperience" contains 9 null/NaN values.
#
# Sheet "AdministratorsExperience" contains 5 null/NaN values.
#
# Sheet "StudentToStaffRatios" contains 0 null/NaN values.
#
# Sheet "TeachersAdminsLevelOfEducation" contains 668 null/NaN values.
#
# Sheet "TeachersAdminsOneYearRetention" contains 2 null/NaN values.

# %% [markdown]
# It is important to note that most features contain at least one NaN value. We will have to address these appropriately as we handle each feature individually.

# %% [markdown]
# -------------------------------------------------------

# %% [markdown]
# **Note to Reader (AKA Professor Gutu):**
#
# So far, my project is in accordance with the objective timeline as listed on my project overview statement, but I had honestly hoped to be a bit further along at this point. I did admittedly struggle to find the appropriate dataset and the most useful features to compare, but now that I have this foundation I think I should be able to pick up speed. For the next code draft submission, according to my objective timeline, I need to conduct exploratory data analysis, incorporate feature engineering, and develop my machine learning prediction model! In addition, I will be sure to clean up any previous parts along the way.
#
# Looking forward to presenting you with my next draft, as well as hearing your comments/critiques for this draft!
